# %% [markdown]
# Advanced Data Analysis and Manipulation with Pandas Demo

# %% [markdown]
# Analyze a dataset of tweets to find the most frequent hashtags and mentions. Use Pandas to load and manipulate the dataset, and then generate statistics to identify the most commonly used hashtags and mentions.
#
# Importing pandas, and giving it an alias of pd

# %%
import pandas as pd

# %% [markdown]
# We used [Mockaroo](https://www.mockaroo.com/) to generate our fake data. If you'd like, and I highly suggest it, look at the Twitter API, learn how to create a developer account, and get real data from that API.
#
# But for the simplicity of this project, we're going to use Mockaroo to get fake data and work with that. With our generated data, we are going to read it and parse it into a Pandas Data frame using
#
# **Remeber to add the .csv file into our Google CoLabs file directors, this is located on the left hand side of the website. Keep in mind it remains per session, meaning if you leave the page, then you'll have to add it again!**
#
# ```
# # pd.read_csv("URL / Local Path")
# ```

# %%
df = pd.read_csv("./MOCK_DATA.csv")

# %%
df.head(10)
# Out:
#   first_name    last_name                    email        date     hashtag  \
# 0     Felice      Raffles      fraffles0@yandex.ru    1/5/2023      Purple
# 1   Dorolice     Bruckent       dbruckent1@icio.us    7/3/2023      Maroon
# 2      Neale         Duer         nduer2@mysql.com  10/23/2022  Aquamarine
# 3        Dot       Torfin         dtorfin3@wix.com   12/7/2022   Goldenrod
# 4    Caresse      Rubinek  crubinek4@webeden.co.uk  11/12/2022        Blue
# 5    Arluene       Bedell         abedell5@tiny.cc   4/20/2023        Pink
# 6   Dorolice      Suttill  dsuttill6@bigcartel.com   3/29/2023      Maroon
# 7    Nikolia      MacColl      nmaccoll7@imgur.com   7/29/2023      Maroon
# 8     Mickey  Sainte Paul    msaintepaul8@cnbc.com   3/13/2023      Violet
# 9     Ingrid     Salvidge   isalvidge9@walmart.com    5/4/2023  Aquamarine
#
#     mentions                                            message
# 0  Chevrolet  magnis dis parturient montes nascetur ridiculu...
# ...

# %% [markdown]
# In order to organize the data and find the most commonly used hashtags / mentions, we'll need to use the following function
#
# ```
# # df["Column Name"].value_counts()
# ```
#
# This will take a column, and then count how many values appear in the DataFrame, it'll organize as well based on the hightest number in ascending order!

# %%
df["hashtag"].value_counts()
# Out:
# Goldenrod     62
# Pink          61
# Khaki         61
# Maroon        60
# Turquoise     60
# Red           57
# Violet        55
# Teal          55
# Aquamarine    53
# Puce          53
# Mauv          53
# Green         52
# Indigo        52
# Blue          48
# Yellow        47
# Fuscia        47
# Purple        46
# Crimson       44
# Orange        34
# Name: hashtag, dtype: int64

# %%
df["mentions"].value_counts()
# Out:
# Ford             81
# Chevrolet        68
# Dodge            51
# Toyota           49
# GMC              43
# Mitsubishi       41
# Mazda            38
# Pontiac          36
# Volkswagen       36
# Nissan           34
# Audi             32
# Mercedes-Benz    32
# BMW              30
# Subaru           27
# Honda            27
# Buick            27
# Infiniti         23
# Mercury          21
# Lexus            21
# Suzuki           20
# Acura            17
# Chrysler         16
# Cadillac         16
# Hyundai          15
# Land Rover       14
# Porsche          12
# Volvo            12
# Bentley          11
# Lincoln          10
# Oldsmobile       10
# Jaguar           10
# Maserati          9
# Isuzu             9
# Jeep              9
# Saab              9
# Kia               9
# Aston Martin      7
# Saturn            7
# MINI              6
# Lotus             6
# Scion             5
# Ferrari           5
# Maybach           5
# Plymouth          5
# Hummer            5
# ...
