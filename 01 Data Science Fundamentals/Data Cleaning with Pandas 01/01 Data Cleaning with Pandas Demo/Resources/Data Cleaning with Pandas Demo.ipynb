# %%
import pandas as pd
import numpy as np
from scipy import stats

# %%
df = pd.read_csv("./sample_data/california_housing_test.csv")

# %%
df.head(10)
# Out:
#    longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0    -122.05     37.37                27.0       3885.0           661.0
# 1    -118.30     34.26                43.0       1510.0           310.0
# 2    -117.81     33.78                27.0       3589.0           507.0
# 3    -118.36     33.82                28.0         67.0            15.0
# 4    -119.67     36.33                19.0       1241.0           244.0
# 5    -119.56     36.51                37.0       1018.0           213.0
# 6    -121.43     38.63                43.0       1009.0           225.0
# 7    -120.65     35.48                19.0       2310.0           471.0
# 8    -122.84     38.40                15.0       3080.0           617.0
# 9    -118.02     34.08                31.0       2402.0           632.0
#
#    population  households  median_income  median_house_value
# 0      1537.0       606.0         6.6085            344700.0
# ...

# %%
df_miss = pd.read_csv("./sample_data/california_housing_test_incomplete.csv")

# %%
df_miss.head(10)
# Out:
#    longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0    -122.05     37.37                  27       3885.0             661
# 1    -118.30     34.26                  43          NaN             310
# 2    -117.81     33.78                  27          NaN             507
# 3    -118.36     33.82                  28          NaN              15
# 4    -119.67     36.33                  19          NaN             244
# 5    -119.56     36.51                  37          NaN             213
# 6    -121.43     38.63                  43          NaN             225
# 7    -120.65     35.48                  19          NaN             471
# 8    -122.84     38.40                  15          NaN             617
# 9    -118.02     34.08                  31          NaN             632
#
#    population  households  median_income  median_house_value
# 0        1537         606         6.6085              344700
# ...

# %%
print(df_miss.isnull())
# Out:
#       longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0         False     False               False        False           False
# 1         False     False               False         True           False
# 2         False     False               False         True           False
# 3         False     False               False         True           False
# 4         False     False               False         True           False
# ...         ...       ...                 ...          ...             ...
# 2995      False     False               False        False           False
# 2996      False     False               False        False           False
# 2997      False     False               False        False           False
# 2998      False     False               False        False           False
# 2999      False     False               False        False           False
#
#       population  households  median_income  median_house_value
# ...

# %%
df_miss.sort_values("median_house_value", ascending=True).head(10)
# Out:
#      longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 260    -119.03     35.38                  52          NaN             290
# 223    -118.27     34.10                  50          NaN             398
# 222    -118.19     33.91                  43          NaN             357
# 221    -121.49     38.51                  30          NaN             607
# 220    -122.18     37.78                  33          NaN              31
# 219    -117.90     33.60                  25          NaN             585
# 218    -122.28     38.34                  44          NaN             190
# 217    -117.18     34.48                   8          NaN             691
# 224    -121.44     38.61                  34          NaN              38
# 216    -121.64     37.14                  14          NaN            1024
#
#      population  households  median_income  median_house_value
# 260         540         260         2.7312                   0
# ...

# %%
df_miss.fillna(0, inplace=True)
df_miss.head(10)
# Out:
#    longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0    -122.05     37.37                  27       3885.0             661
# 1    -118.30     34.26                  43          0.0             310
# 2    -117.81     33.78                  27          0.0             507
# 3    -118.36     33.82                  28          0.0              15
# 4    -119.67     36.33                  19          0.0             244
# 5    -119.56     36.51                  37          0.0             213
# 6    -121.43     38.63                  43          0.0             225
# 7    -120.65     35.48                  19          0.0             471
# 8    -122.84     38.40                  15          0.0             617
# 9    -118.02     34.08                  31          0.0             632
#
#    population  households  median_income  median_house_value
# 0        1537         606         6.6085              344700
# ...

# %%
z = np.abs(stats.zscore(df_miss))
print(z)
# Out:
#       longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0      1.233729  0.814633            0.147000     0.690086        0.315337
# 1      0.646344  0.645931            1.127565     1.109001        0.529255
# 2      0.892007  0.871356            0.147000     1.109001        0.055225
# 3      0.616263  0.852570            0.067340     1.109001        1.239098
# 4      0.040509  0.326213            0.784282     1.109001        0.688068
# ...         ...       ...                 ...          ...             ...
# 2995   0.135766  0.570789            0.465641     0.437527        0.269618
# 2996   0.726560  0.739858            0.147000     1.325439        1.328367
# 2997   0.055550  0.312124            1.501225     0.666291        0.791536
# 2998   1.237940  0.721072            0.888584     1.064545        1.241504
# 2999   0.020455  0.570789            1.047905     0.291655        0.642349
#
#       population  households  median_income  median_house_value
# ...

# %%
threshold = 1.25
df_fixed = df_miss[(z < threshold).all(axis=1)]
df_fixed
# Out:
#       longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 304     -117.84     35.35                  28       1913.0             486
# 309     -118.27     34.11                  36       1832.0             539
# 310     -118.44     34.30                  38       1595.0             314
# 311     -121.77     37.68                  41       1501.0             299
# 318     -118.07     33.91                  29       2387.0             570
# ...         ...       ...                 ...          ...             ...
# 2985    -120.47     34.94                  17       1368.0             308
# 2987    -121.97     37.29                  25       4096.0             743
# 2988    -122.01     36.97                  43       2162.0             509
# 2989    -122.02     37.60                  32       1295.0             295
# 2994    -117.93     33.86                  35        931.0             181
#
#       population  households  median_income  median_house_value
# ...
